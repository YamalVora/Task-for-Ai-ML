# %%
import pandas as pd 
myfile=pd.read_csv('student.csv')  #will load the csv file 
print(myfile.to_string)
# Out:
# <bound method DataFrame.to_string of     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
print(len(myfile)) #total number of students
# Out:
# 1000

# %%
newfile3=myfile[myfile["study_hours_per_day"]>2] #no of students with study hours more than 2 
num3=len(newfile3)
print(num3)
# Out:
# 846

# %%
myfile[myfile["exam_score"]>40]
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 4        S1004   19  Female                  5.0                 4.4
# 5        S1005   24    Male                  7.2                 1.3
# 6        S1006   21  Female                  5.6                 1.5
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
newfile=myfile[(myfile["study_hours_per_day"]>2) & (myfile["exam_score"]>40)]
num1=len(newfile)
print(num1/1000*100)   #percentage of students with study hours more than 2 and passed exam
# Out:
# 84.2

# %%
#bayes theorem to find probability that student studied more than 2 hours given the student passed 
#P(studied>2hours|passed)=[P(passed|studied>2hours) X P(studied)]/[P(passed)]
#P(passed)=[P(passed|studied>2hours) X P(studied) + P(passed/didntstudy) X P(didntstudy)]
#this is the formula 
#now, I did math in notebook and found the inputs by len/1000 of every condition and I got:
#P(passed)=0.7251
#P(studied>2hours)=0.846
#P(didnt study)=0.133
#P(passed/didntstudy)=0.096
#P(passed|studied)=0.842
#therefore, using baye's P(studied>2hours|passed) = 0.98239
#I could have compiled everything and found by code but it would be too tedius 
print(0.98239)
# Out:
# 0.98239
